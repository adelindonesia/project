# %%
## Set up
from selenium import webdriver
from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains

import datetime
import time

import pandas as pd

# options = Options()
# options.add_experimental_option("detach", True)

# path = "C:\Program Files (x86)\chromedriver.exe"

# driver = webdriver.Chrome(path, options=options)

driver = webdriver.Chrome()
driver.implicitly_wait(5)

# %%
def page(driver=driver, url: str= "https://www.booking.com/"):
    driver.get(url)
    driver.maximize_window()

# %%
def accept_coockies(driver = driver, popup_name: str = "onetrust-accept-btn-handler") -> None:
    driver.find_element(By.ID, popup_name).click()

def manage_coockies(driver = driver, popup_name: str = "onetrust-pc-btn-handler") -> None:
    driver.find_element(By.ID, popup_name).click()
    driver.find_element(By.XPATH, "//button[text()='Confirm My Choices']").click()

def go_to_flights(driver = driver, name = "Flights"):
    driver.find_element(By.LINK_TEXT, name).click()

# %%
def input_from_city_airport(driver = driver, city: str = "brussels", airport: str = "AIRPORTBRU") -> None:
    driver.find_element(By.CSS_SELECTOR, "button[data-ui-name='input_location_from_segment_0']").click()

    # Clear bar to avoid unwanted input
    driver.find_element(By.CSS_SELECTOR, ".css-rh2lq6").click()

    # Input departure city
    fly_from = driver.find_element(By.CSS_SELECTOR, "input[data-ui-name='input_text_autocomplete']")
    fly_from.send_keys('  ' + city.lower())
    fly_from_airport = driver.find_element(By.CSS_SELECTOR, f"input[name='{airport.upper()}']")
    fly_from_airport.click()

# %%
def input_to_city_airport(driver = driver, city: str = "jakarta", airport: str = "AIRPORTCGK") -> None:
    driver.find_element(By.CSS_SELECTOR, "button[data-ui-name='input_location_to_segment_0']").click()
    fly_to = driver.find_element(By.CSS_SELECTOR, "input[data-ui-name='input_text_autocomplete']")
    fly_to.send_keys('  ' + city.lower())
    fly_to_airport = driver.find_element(By.CSS_SELECTOR, f"input[name='{airport.upper()}']")
    fly_to_airport.click()

# %%
def round_trip_date_chooser(driver=driver, css_from_date: str= 'span[data-date="2023-08-01"]', css_to_date: str='span[data-date="2023-08-15"]'):
    date_roundtrip_click = driver.find_element(By.CSS_SELECTOR, 'button[data-ui-name="button_date_segment_0"]')
    date_roundtrip_click.click()
    arrow = driver.find_element(By.CSS_SELECTOR, 'button[class="Actionable-module__root___lQCcK Button-module__root___puEjU Button-module__root--variant-tertiary___MhiYJ Button-module__root--icon-only___uhCdT Button-module__root--size-large___Oef9C Button-module__root--wide-false___ngEa+ Button-module__root--variant-tertiary-neutral___zGwxJ Calendar-module__control___5hEew Calendar-module__control--next___N9ipu"]')
    arrow.click()
    dep_date_button = driver.find_element(By.CSS_SELECTOR, css_from_date)
    dep_date_button.click()
    arr_date_button = driver.find_element(By.CSS_SELECTOR, css_to_date)
    arr_date_button.click()
    search_click = driver.find_element(By.CSS_SELECTOR, 'button[data-ui-name="button_search_submit"]')
    search_click.click()

# %%
def airline_chooser(driver = driver, airline_1: str= "Lufthansa", airline_2: str="Qatar Airways"):
    # time.sleep(2)
    # driver.execute_script("window.scrollTo(0,400)")
    time.sleep(2)
    ticket_type = driver.find_element(By.CSS_SELECTOR, ".Link-module__root--variant-primary___skVxI, .Link-module__root--variant-secondary___IJWjg")
    ticket_type.click()
    time.sleep(2)
    element_to_hover_over = driver.find_element(By.CSS_SELECTOR, "[data-testid='search_filter_airline_" + airline_1 + "']")
    hover = ActionChains(driver).move_to_element(element_to_hover_over)
    hover.perform()
    time.sleep(2)
    air_1 = driver.find_element(By.CSS_SELECTOR, 'button[class="Actionable-module__root___lQCcK Link-module__root___Jo24k Link-module__root--variant-primary___skVxI"]')
    air_1.click()
    air_2 = driver.find_element(By.CSS_SELECTOR, "[data-testid='search_filter_airline_" + airline_2 + "']" )
    air_2.click()

# %%
def scrape_card(card_number: int=0) -> dict:
    """
    Function that generates a dictionary of a specific flight-card (in this case round-trip ticket).

    Args:
    -----
        card_number (int): number of flight card interested in
                        (Default sets to 0)

    Returns:
    --------
        dict: dictionnary

    Comments:
    ---------
        flight-cards: the offred results obtain when searching flight tickets. 
                        A flight-card includes relevant information of a flight-ticket.
        
        card_number: always starts at 0, 
                    i.e., the number of the first flight-card is 0.
        
        dictionnary: it contains 18 values which are,

            airline_company : name of the airline company
            dep_city        : departure city (where the flight starts form)
            arr_city        : arrival city (the destination of the flight)
            out_dep_date    : departure day of the outbound flight
            out_dep_time    : departure time of the outbound flight
            out_duration    : lenght (duration) of the outbound flight
            out_stop_number : number of stopover(s) or layover(s)
            out_arr_date    : arrival day of the outbound flight
            out_arr_time    : arrival time of the outbound flight
            in_dep_date     : departure day of the inbound flight
            in_dep_time     : departure time of the inbound flight
            in_duration     : lenght of the inbound flight
            in_stop_num     : number of stopover(s) or layover(s)
            in_arr_date     : arrival day of the inbound flight
            in_arr_time     : arrival time of the inbound flight
            price_ticket    : flight price ticket

            hour_scrap     : hour in which the scrap has been done
            day_scrap      : day which the scrap has been performed
    """
    ticket = {}
    
    ticket['airline_company']= driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[3]/div/div/div'
        ).text
    
    ticket['dep_city'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[1]/div[2]/div[1]'
        ).text
    
    ticket['arr_city'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[3]/div[2]/div[1]'
        ).text
    
    ticket['out_dep_date'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[1]/div[2]/div[3]'
        ).text

    ticket['out_dep_time'] =  driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[1]/div[1]'
        ).text
    
    ticket['out_duration'] = driver.find_element(
        By.XPATH, f"//*[@id='flight-card-{card_number}']/div/div/div[1]/div[1]/div[2]/div/div/div[2]/div[1]"
        ).text
    
    ticket['out_stop_num'] = driver.find_element(
        By.XPATH, f"//*[@id='flight-card-{card_number}']/div/div/div[1]/div[1]/div[2]/div/div/div[2]/div[3]"
        ).text
    
    ticket['out_arr_date'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[3]/div[2]/div[3]'
        ).text
    
    ticket['out_arr_time'] = driver.find_element(
        By.XPATH, f"//*[@id='flight-card-{card_number}']/div/div/div[1]/div[1]/div[2]/div/div/div[3]/div[1]"
        ).text
    
    ticket['in_dep_date'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[1]/div[2]/div[3]'
        ).text
    
    ticket['in_dep_time'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[1]/div[1]'
        ).text
    
    ticket['in_duration'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[2]/div[1]'
        ).text
    
    ticket['in_stop_num'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[2]/div[3]'
        ).text

    ticket['in_arr_date'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[3]/div[2]/div[3]'
        ).text
    
    ticket['in_arr_time'] = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[4]/div[2]/div/div/div[3]/div[1]'
        ).text
    
    see_flight = driver.find_element(
        By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[2]/div[2]/button'
    ).click()

    container = driver.find_elements(By.CSS_SELECTOR, ".SheetContainer-module__content___WX8xI")
    ticket['price_ticket'] = container[0].find_element(
        By.CSS_SELECTOR, ".css-vxcmzt"
        ).text
    driver.back()


    current_time = datetime.datetime.now()

    ticket['hour_scrap'] = current_time.hour
    ticket['day_scrap'] = current_time.day
    
    return(ticket)

# %%
my_dict = []
def scrape_cards(my_dict: list=[])->list:
    """
    Function that generates list of dictionaries of n flight-card(s) for one search result page.

    Args:
    -----
        n_cards (int): n first flight-card(s)
                            (Default sets to total number of flight-cards in one page)
    
    Returns:
    --------
        list: list of dictionnaries
    """
    n_cards = len(driver.find_elements(By.CSS_SELECTOR, ".css-4o3ibe"))

    for i in range(0, n_cards-1):
        my_dict.append(scrape_card(i))

    return(my_dict)

# %%
def get_pages(tot_pages):

    for i in range(1, tot_pages+1):
        print(f"Scraping page {i}")
        scrape_cards(my_dict)
        time.sleep(2)
        next_button = driver.find_element(By.CSS_SELECTOR, f'button[aria-label=" {i}"]')
        next_button.click()
        time.sleep(3)
    
    scrape_cards(my_dict)
    
    return(my_dict)

# %%
page()
manage_coockies()
go_to_flights()
input_from_city_airport()
input_to_city_airport()
round_trip_date_chooser()

# %%
airline_chooser(airline_1= "Lufthansa", airline_2="Qatar Airways")

# %%
tot_pages = len(driver.find_elements(By.CSS_SELECTOR, '.Pagination-module__link___XUrx7, .Pagination-module__link___XUrx7:link, .Pagination-module__link___XUrx7:visited, .Pagination-module__separator___hRwOo'))
get_pages(tot_pages)
# Out:
# Scraping page 1
# Scraping page 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 tot_pages = len(driver.find_elements(By.CSS_SELECTOR, '.Pagination-module__link___XUrx7, .Pagination-module__link___XUrx7:link, .Pagination-module__link___XUrx7:visited, .Pagination-module__separator___hRwOo'))
# ----> 2 get_pages(tot_pages)
#
# Cell In[10], line 5, in get_pages(tot_pages)
#       3 for i in range(1, tot_pages+1):
#       4     print(f"Scraping page {i}")
# ----> 5     scrape_cards(my_dict)
#       6     time.sleep(2)
#       7     next_button = driver.find_element(By.CSS_SELECTOR, f'button[aria-label=" {i}"]')
#
# Cell In[9], line 18, in scrape_cards(my_dict)
#      15 n_cards = len(driver.find_elements(By.CSS_SELECTOR, ".css-4o3ibe"))
#      17 for i in range(0, n_cards-1):
# ---> 18     my_dict.append(scrape_card(i))
#      20 return(my_dict)
#
# Cell In[8], line 62, in scrape_card(card_number)
#      54 ticket['arr_city'] = driver.find_element(
#      55     By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[3]/div[2]/div[1]'
#      56     ).text
#      58 ticket['out_dep_date'] = driver.find_element(
#      59     By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[1]/div[2]/div[3]'
#      60     ).text
# ---> 62 ticket['out_dep_time'] =  driver.find_element(
#      63     By.XPATH, f'//*[@id="flight-card-{card_number}"]/div/div/div[1]/div[1]/div[2]/div/div/div[1]/div[1]'
#      64     ).text
#      66 ticket['out_duration'] = driver.find_element(
#      67     By.XPATH, f"//*[@id='flight-card-{card_number}']/div/div/div[1]/div[1]/div[2]/div/div/div[2]/div[1]"
#      68     ).text
#      70 ticket['out_stop_num'] = driver.find_element(
#      71     By.XPATH, f"//*[@id='flight-card-{card_number}']/div/div/div[1]/div[1]/div[2]/div/div/div[2]/div[3]"
#      72     ).text
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Adeli\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
cur_time = datetime.datetime.now()
day = cur_time.day
hour = cur_time.hour

df = pd.DataFrame(my_dict)
df.to_csv(f'booking_{day}_may_{hour}_pm.csv', index=False)
df.to_excel(f'booking_{day}_may_{hour}_pm.xlsx', index=False)

# %%
import shutil

shutil.move(f'booking_{day}_may_{hour}_pm.csv', 'Bxl_Jakarta')
shutil.move(f'booking_{day}_may_{hour}_pm.xlsx', 'Bxl_Jakarta')
# Out:
# 'Bxl_Jakarta\\booking_15_may_7_pm.xlsx'

# %%
go_to_flights()
input_from_city_airport()
input_to_city_airport(city="tokyo", airport='AIRPORTHND')
round_trip_date_chooser()

# %%
airline_chooser(airline_1= "Lufthansa", airline_2="Qatar Airways")

# %%
tot_pages = len(driver.find_elements(By.CSS_SELECTOR, '.Pagination-module__link___XUrx7, .Pagination-module__link___XUrx7:link, .Pagination-module__link___XUrx7:visited, .Pagination-module__separator___hRwOo'))
get_pages(tot_pages)
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7
# [{'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '17h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '7:40 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:05 AM',
#   'in_duration': '34h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '2:10 PM',
#   'price_ticket': '1 603,76 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Qatar Airways',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '17h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '7:40 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 340,21 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Qatar Airways',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '31h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:30 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:05 AM',
#   'in_duration': '34h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '2:10 PM',
#   'price_ticket': '1 607,03 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 458,39 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Qatar Airways',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '17h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '7:40 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:05 AM',
#   'in_duration': '34h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '2:10 PM',
#   'price_ticket': '1 603,76 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Qatar Airways',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '17h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '7:40 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 340,21 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Qatar Airways',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:05 AM',
#   'out_duration': '31h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:30 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:05 AM',
#   'in_duration': '34h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '2:10 PM',
#   'price_ticket': '1 607,03 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 458,39 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:45 PM',
#   'out_duration': '23h 20m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 485,59 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 20m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:20 AM',
#   'price_ticket': '2 691,82 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '22h 40m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 691,82 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '23h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 491,82 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '23h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 491,82 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 491,82 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '17h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 20m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:20 AM',
#   'price_ticket': '2 685,59 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 685,59 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '23h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '23h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '22h 40m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 458,39 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '25h 10m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 485,59 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '17h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 472,62 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:45 PM',
#   'out_duration': '23h 20m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '25h 10m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '18h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 475,48 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '23h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:45 PM',
#   'out_duration': '23h 20m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '19h 00m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '23h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '23h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '23h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 20m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:20 AM',
#   'price_ticket': '2 685,59 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '22h 40m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 489,71 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '20h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 458,39 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '25h 10m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 10m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:45 PM',
#   'out_duration': '23h 20m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '4:30 PM',
#   'out_duration': '25h 10m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 35m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by City Jet For Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:15 PM',
#   'out_duration': '22h 25m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '23h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '23h 50m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '6:05 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '22h 25m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '22h 40m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '23h 55m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '1:55 PM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:05 PM',
#   'out_duration': '21h 35m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '25h 50m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '3:50 PM',
#   'price_ticket': '2 508,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 PM',
#   'out_duration': '22h 40m',
#   'out_stop_num': '2 stops',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '10:40 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '7:00 PM',
#   'in_duration': '20h 20m',
#   'in_stop_num': '2 stops',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:20 AM',
#   'price_ticket': '2 502,68 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'CGK',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:45 PM',
#   'out_duration': '23h 20m',
# ...
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 222,80 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:35 AM',
#   'out_duration': '15h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '17h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 15',
#   'in_arr_time': '10:35 PM',
#   'price_ticket': '2 826,63 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 AM',
#   'out_duration': '19h 50m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '21h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 391,28 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:55 AM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '27h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 229,91 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:35 AM',
#   'out_duration': '15h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '5:20 PM',
#   'price_ticket': '2 377,01 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:15 AM',
#   'out_duration': '18h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '19h 40m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '11:20 AM',
#   'out_duration': '15h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '5:20 PM',
#   'price_ticket': '2 390,31 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:50 AM',
#   'out_duration': '16h 10m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '17h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 15',
#   'in_arr_time': '10:35 PM',
#   'price_ticket': '2 826,63 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '20h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '18h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 390,31 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 AM',
#   'out_duration': '19h 50m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 231,41 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:05 PM',
#   'out_duration': '15h 40m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '19h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '19h 40m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:30 AM',
#   'out_duration': '17h 20m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '29h 30m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 237,03 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:55 AM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '29h 30m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:45 PM',
#   'out_duration': '26h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 3',
#   'out_arr_time': '6:15 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '17h 25m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 15',
#   'in_arr_time': '8:05 PM',
#   'price_ticket': '2 375,57 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 AM',
#   'out_duration': '19h 50m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '27h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:35 AM',
#   'price_ticket': '2 244,14 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:30 AM',
#   'out_duration': '17h 20m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '5:20 PM',
#   'price_ticket': '2 390,31 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '20h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '19h 40m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:10 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:35 AM',
#   'out_duration': '15h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '20h 05m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '10:35 AM',
#   'price_ticket': '2 826,63 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '9:35 AM',
#   'out_duration': '15h 25m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '28h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:55 AM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '5:20 PM',
#   'price_ticket': '2 377,01 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:15 AM',
#   'out_duration': '18h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '21h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:55 AM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '17h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 15',
#   'in_arr_time': '10:35 PM',
#   'price_ticket': '2 826,63 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 AM',
#   'out_duration': '19h 50m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '29h 30m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '8:10 AM',
#   'price_ticket': '2 237,03 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:50 AM',
#   'out_duration': '16h 10m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '28h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 395,02 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:15 AM',
#   'out_duration': '18h 35m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 396,20 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:45 PM',
#   'out_duration': '26h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 3',
#   'out_arr_time': '6:15 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '19h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 15',
#   'in_arr_time': '10:30 PM',
#   'price_ticket': '2 376,53 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '2:40 PM',
#   'out_duration': '19h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 396,52 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '7:00 AM',
#   'out_duration': '19h 50m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '9:50 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '5:20 PM',
#   'price_ticket': '2 391,28 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '20h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:30 PM',
#   'in_duration': '21h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '12:25 PM',
#   'price_ticket': '2 572,86 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa, operated by Brussels Airlines',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '6:55 AM',
#   'out_duration': '18h 05m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '8:00 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '9:40 AM',
#   'in_duration': '28h 55m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 396,52 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '1:15 PM',
#   'out_duration': '20h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 2',
#   'out_arr_time': '4:45 PM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 396,52 €',
#   'hour_scrap': 7,
#   'day_scrap': 15},
#  {'airline_company': 'Lufthansa',
#   'dep_city': 'BRU',
#   'arr_city': 'HND',
#   'out_dep_date': 'Aug 1',
#   'out_dep_time': '8:45 PM',
#   'out_duration': '26h 30m',
#   'out_stop_num': '1 stop',
#   'out_arr_date': 'Aug 3',
#   'out_arr_time': '6:15 AM',
#   'in_dep_date': 'Aug 15',
#   'in_dep_time': '11:45 AM',
#   'in_duration': '26h 50m',
#   'in_stop_num': '1 stop',
#   'in_arr_date': 'Aug 16',
#   'in_arr_time': '7:35 AM',
#   'price_ticket': '2 389,80 €',
#   'hour_scrap': 7,
#   'day_scrap': 15}]

# %%
df1 = pd.DataFrame(my_dict)
df1.to_csv(f'booking_{day}_may_{hour}_pm.csv', index=False)
df1.to_excel(f'booking_{day}_may_{hour}_pm.xlsx', index=False)

# %%
shutil.move(f'booking_{day}_may_{hour}_pm.csv', 'Bxl_Tokyo')
shutil.move(f'booking_{day}_may_{hour}_pm.xlsx', 'Bxl_Tokyo')
# Out:
# 'Bxl_Tokyo\\booking_15_may_7_pm.xlsx'
