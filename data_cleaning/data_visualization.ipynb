# %%
import pandas as pd

# %%
# %run data_cleaning.ipynb

# %%
Jakarta_cleaned_data
# Out:
#      airline_company dep_city arr_city out_dep_date out_dep_time  \
# 0      Qatar Airways      BRU      CGK   2023-08-01        09:05
# 1      Qatar Airways      BRU      CGK   2023-08-01        09:05
# 2      Qatar Airways      BRU      CGK   2023-08-01        09:05
# 3          Lufthansa      BRU      CGK   2023-08-01        20:05
# 4          Lufthansa      BRU      CGK   2023-08-01        20:05
# ...              ...      ...      ...          ...          ...
# 1394       Lufthansa      BRU      CGK   2023-08-01        16:30
# 1395       Lufthansa      BRU      CGK   2023-08-01        13:15
# 1396       Lufthansa      BRU      CGK   2023-08-01        13:45
# 1397       Lufthansa      BRU      CGK   2023-08-01        19:00
# 1398       Lufthansa      BRU      CGK   2023-08-01        18:05
#
#         out_duration out_stop_num out_arr_date out_arr_time in_dep_date  \
# 0    0 days 17:35:00            1   2023-08-02        07:40  2023-08-15
# ...

# %%
Tokyo_cleaned_data
# Out:
#      airline_company dep_city arr_city out_dep_date out_dep_time  \
# 0          Lufthansa      BRU      HND   2023-08-01        09:35
# 1          Lufthansa      BRU      HND   2023-08-01        11:20
# 2          Lufthansa      BRU      HND   2023-08-01        08:50
# 3          Lufthansa      BRU      HND   2023-08-01        09:30
# 4          Lufthansa      BRU      HND   2023-08-01        09:35
# ...              ...      ...      ...          ...          ...
# 1342       Lufthansa      BRU      HND   2023-08-01        06:55
# 1343       Lufthansa      BRU      HND   2023-08-01        09:30
# 1344       Lufthansa      BRU      HND   2023-08-01        14:40
# 1345       Lufthansa      BRU      HND   2023-08-01        13:15
# 1346       Lufthansa      BRU      HND   2023-08-01        09:30
#
#         out_duration out_stop_num out_arr_date out_arr_time in_dep_date  \
# 0    0 days 15:25:00            1   2023-08-02        08:00  2023-08-15
# ...
